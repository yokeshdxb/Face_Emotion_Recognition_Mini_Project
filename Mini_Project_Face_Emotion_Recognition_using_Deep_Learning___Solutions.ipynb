# %% [markdown]
# # 📌 Step 1: Install Required Libraries

# %%
# !pip install kaggle --quiet
# !pip install tensorflow matplotlib seaborn --quiet

# %% [markdown]
# # 📌 Step 2: Upload Your Kaggle API Token
# Go to https://www.kaggle.com/settings
#
# Scroll down to “API” and click “Create New API Token”
#
# Upload the kaggle.json file in Colab

# %%
#kaggle_api = '/content/drive/MyDrive/Black Elephant/Kaggle_API/kaggle.json'

kaggle_api = '/content/kaggle.json'

# %%
# Copy Kaggle API Key from Drive to .kaggle/
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # 📌 Step 3: Download FER2013 Dataset from Kaggle

# %%
# !kaggle datasets download -d msambare/fer2013
# !unzip -q fer2013.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#   0% 0.00/60.3M [00:00<?, ?B/s]
# 100% 60.3M/60.3M [00:00<00:00, 1.39GB/s]

# %% [markdown]
# # 📌 Step 4: Set Up Image Data Loaders

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Base directory
train_dir = "/content/train"
test_dir = "/content/test"

# Create ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    horizontal_flip=True,
    fill_mode="nearest",
    validation_split=0.2
)



'''
    rescale=1./255,
    validation_split=0.2,  # 20% of training data for validation
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
'''


# Training generator (80% of train data)
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation generator (20% of train data)
val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
val_generator = val_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Test generator (no split needed)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 📌 Step 5: Build the CNN Model

# %%
'''
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
'''

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.3),

    Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 emotion classes
])

from tensorflow.keras.losses import CategoricalCrossentropy
model.compile(optimizer='adam',
              loss=CategoricalCrossentropy(label_smoothing=0.1),
              metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 21, 21, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,472,711 (9.43 MB)
#  Trainable params: 2,471,815 (9.43 MB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# # 📌 Step 6: Train the Model

# %%
'''
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=[early_stop, reduce_lr]
)
'''
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=300,
    #callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# Epoch 1/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5489 - loss: 1.3746 - val_accuracy: 0.6053 - val_loss: 1.2631
# Epoch 2/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5576 - loss: 1.3659 - val_accuracy: 0.6063 - val_loss: 1.2654
# Epoch 3/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5508 - loss: 1.3748 - val_accuracy: 0.6081 - val_loss: 1.2641
# Epoch 4/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5518 - loss: 1.3723 - val_accuracy: 0.6060 - val_loss: 1.2646
# Epoch 5/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5576 - loss: 1.3671 - val_accuracy: 0.6062 - val_loss: 1.2636
# Epoch 6/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.5536 - loss: 1.3650 - val_accuracy: 0.6062 - val_loss: 1.2632
# Epoch 7/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5573 - loss: 1.3658 - val_accuracy: 0.6053 - val_loss: 1.2615
# Epoch 8/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5542 - loss: 1.3668 - val_accuracy: 0.6046 - val_loss: 1.2680
# Epoch 9/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5518 - loss: 1.3728 - val_accuracy: 0.6069 - val_loss: 1.2649
# Epoch 10/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5607 - loss: 1.3598 - val_accuracy: 0.6088 - val_loss: 1.2624
# Epoch 11/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5511 - loss: 1.3679 - val_accuracy: 0.6029 - val_loss: 1.2723
# Epoch 12/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5564 - loss: 1.3649 - val_accuracy: 0.6086 - val_loss: 1.2648
# Epoch 13/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5602 - loss: 1.3575 - val_accuracy: 0.6079 - val_loss: 1.2606
# Epoch 14/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.5543 - loss: 1.3662 - val_accuracy: 0.6079 - val_loss: 1.2655
# Epoch 15/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.5598 - loss: 1.3627 - val_accuracy: 0.6069 - val_loss: 1.2637
# Epoch 16/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5578 - loss: 1.3630 - val_accuracy: 0.6067 - val_loss: 1.2642
# Epoch 17/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5641 - loss: 1.3556 - val_accuracy: 0.6067 - val_loss: 1.2638
# Epoch 18/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5593 - loss: 1.3668 - val_accuracy: 0.6062 - val_loss: 1.2702
# Epoch 19/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5499 - loss: 1.3812 - val_accuracy: 0.6084 - val_loss: 1.2634
# Epoch 20/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5608 - loss: 1.3589 - val_accuracy: 0.6060 - val_loss: 1.2606
# Epoch 21/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5501 - loss: 1.3701 - val_accuracy: 0.6049 - val_loss: 1.2604
# Epoch 22/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5676 - loss: 1.3516 - val_accuracy: 0.6043 - val_loss: 1.2711
# Epoch 23/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5559 - loss: 1.3613 - val_accuracy: 0.6079 - val_loss: 1.2623
# Epoch 24/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5558 - loss: 1.3618 - val_accuracy: 0.6086 - val_loss: 1.2600
# Epoch 25/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5518 - loss: 1.3679 - val_accuracy: 0.6088 - val_loss: 1.2611
# Epoch 26/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5537 - loss: 1.3603 - val_accuracy: 0.6077 - val_loss: 1.2588
# Epoch 27/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5561 - loss: 1.3648 - val_accuracy: 0.6074 - val_loss: 1.2605
# Epoch 28/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5570 - loss: 1.3626 - val_accuracy: 0.6076 - val_loss: 1.2590
# Epoch 29/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5527 - loss: 1.3627 - val_accuracy: 0.6072 - val_loss: 1.2631
# Epoch 30/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5528 - loss: 1.3730 - val_accuracy: 0.6062 - val_loss: 1.2591
# Epoch 31/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5557 - loss: 1.3669 - val_accuracy: 0.6065 - val_loss: 1.2614
# Epoch 32/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5582 - loss: 1.3601 - val_accuracy: 0.6067 - val_loss: 1.2587
# Epoch 33/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5574 - loss: 1.3593 - val_accuracy: 0.6063 - val_loss: 1.2604
# Epoch 34/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.5578 - loss: 1.3643 - val_accuracy: 0.6036 - val_loss: 1.2669
# Epoch 35/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.5616 - loss: 1.3556 - val_accuracy: 0.6069 - val_loss: 1.2584
# Epoch 36/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5576 - loss: 1.3655 - val_accuracy: 0.6076 - val_loss: 1.2607
# Epoch 37/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5594 - loss: 1.3621 - val_accuracy: 0.6079 - val_loss: 1.2609
# Epoch 38/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5716 - loss: 1.3507 - val_accuracy: 0.6096 - val_loss: 1.2615
# Epoch 39/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5563 - loss: 1.3662 - val_accuracy: 0.6065 - val_loss: 1.2600
# Epoch 40/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5573 - loss: 1.3650 - val_accuracy: 0.6037 - val_loss: 1.2659
# Epoch 41/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5517 - loss: 1.3653 - val_accuracy: 0.6065 - val_loss: 1.2656
# Epoch 42/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5645 - loss: 1.3499 - val_accuracy: 0.6084 - val_loss: 1.2603
# Epoch 43/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5622 - loss: 1.3555 - val_accuracy: 0.6096 - val_loss: 1.2570
# Epoch 44/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5596 - loss: 1.3560 - val_accuracy: 0.6046 - val_loss: 1.2668
# Epoch 45/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5598 - loss: 1.3617 - val_accuracy: 0.6055 - val_loss: 1.2587
# Epoch 46/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5591 - loss: 1.3577 - val_accuracy: 0.6070 - val_loss: 1.2627
# Epoch 47/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5647 - loss: 1.3541 - val_accuracy: 0.6086 - val_loss: 1.2582
# Epoch 48/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5577 - loss: 1.3614 - val_accuracy: 0.6049 - val_loss: 1.2631
# Epoch 49/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5582 - loss: 1.3612 - val_accuracy: 0.6063 - val_loss: 1.2611
# Epoch 50/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5632 - loss: 1.3530 - val_accuracy: 0.6063 - val_loss: 1.2604
# Epoch 51/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5577 - loss: 1.3638 - val_accuracy: 0.6067 - val_loss: 1.2600
# Epoch 52/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5644 - loss: 1.3523 - val_accuracy: 0.6046 - val_loss: 1.2604
# Epoch 53/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.5617 - loss: 1.3501 - val_accuracy: 0.6060 - val_loss: 1.2600
# Epoch 54/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5647 - loss: 1.3517 - val_accuracy: 0.6056 - val_loss: 1.2580
# Epoch 55/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5611 - loss: 1.3513 - val_accuracy: 0.6049 - val_loss: 1.2619
# Epoch 56/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5672 - loss: 1.3462 - val_accuracy: 0.6065 - val_loss: 1.2579
# Epoch 57/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5616 - loss: 1.3582 - val_accuracy: 0.6060 - val_loss: 1.2576
# Epoch 58/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5592 - loss: 1.3552 - val_accuracy: 0.6049 - val_loss: 1.2620
# Epoch 59/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5651 - loss: 1.3557 - val_accuracy: 0.6041 - val_loss: 1.2661
# Epoch 60/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5521 - loss: 1.3602 - val_accuracy: 0.6051 - val_loss: 1.2625
# Epoch 61/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.5625 - loss: 1.3544 - val_accuracy: 0.6069 - val_loss: 1.2581
# Epoch 62/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5607 - loss: 1.3569 - val_accuracy: 0.6077 - val_loss: 1.2573
# Epoch 63/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5599 - loss: 1.3593 - val_accuracy: 0.6044 - val_loss: 1.2614
# Epoch 64/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5586 - loss: 1.3538 - val_accuracy: 0.6062 - val_loss: 1.2586
# Epoch 65/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5662 - loss: 1.3433 - val_accuracy: 0.6069 - val_loss: 1.2582
# Epoch 66/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5587 - loss: 1.3642 - val_accuracy: 0.6065 - val_loss: 1.2592
# Epoch 67/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5615 - loss: 1.3545 - val_accuracy: 0.6060 - val_loss: 1.2617
# Epoch 68/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5603 - loss: 1.3562 - val_accuracy: 0.6084 - val_loss: 1.2586
# Epoch 69/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5609 - loss: 1.3559 - val_accuracy: 0.6055 - val_loss: 1.2637
# Epoch 70/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5643 - loss: 1.3507 - val_accuracy: 0.6070 - val_loss: 1.2577
# Epoch 71/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5656 - loss: 1.3436 - val_accuracy: 0.6102 - val_loss: 1.2549
# Epoch 72/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5633 - loss: 1.3501 - val_accuracy: 0.6079 - val_loss: 1.2560
# Epoch 73/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.5572 - loss: 1.3688 - val_accuracy: 0.6062 - val_loss: 1.2605
# Epoch 74/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.5610 - loss: 1.3552 - val_accuracy: 0.6067 - val_loss: 1.2584
# Epoch 75/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5599 - loss: 1.3558 - val_accuracy: 0.6083 - val_loss: 1.2588
# Epoch 76/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.5654 - loss: 1.3509 - val_accuracy: 0.6086 - val_loss: 1.2550
# Epoch 77/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - accuracy: 0.5620 - loss: 1.3648 - val_accuracy: 0.6067 - val_loss: 1.2552
# Epoch 78/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.5567 - loss: 1.3607 - val_accuracy: 0.6081 - val_loss: 1.2558
# Epoch 79/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.5702 - loss: 1.3400 - val_accuracy: 0.6067 - val_loss: 1.2591
# Epoch 80/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.5663 - loss: 1.3491 - val_accuracy: 0.6069 - val_loss: 1.2564
# Epoch 81/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.5642 - loss: 1.3501 - val_accuracy: 0.6053 - val_loss: 1.2636
# Epoch 82/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.5541 - loss: 1.3587 - val_accuracy: 0.6063 - val_loss: 1.2644
# Epoch 83/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 57ms/step - accuracy: 0.5623 - loss: 1.3570 - val_accuracy: 0.6062 - val_loss: 1.2632
# Epoch 84/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5597 - loss: 1.3552 - val_accuracy: 0.6074 - val_loss: 1.2579
# Epoch 85/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5628 - loss: 1.3559 - val_accuracy: 0.6053 - val_loss: 1.2605
# Epoch 86/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.5571 - loss: 1.3558 - val_accuracy: 0.6076 - val_loss: 1.2553
# Epoch 87/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.5647 - loss: 1.3517 - val_accuracy: 0.6081 - val_loss: 1.2558
# Epoch 88/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.5646 - loss: 1.3560 - val_accuracy: 0.6072 - val_loss: 1.2551
# Epoch 89/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.5665 - loss: 1.3499 - val_accuracy: 0.6058 - val_loss: 1.2542
# Epoch 90/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.5582 - loss: 1.3600 - val_accuracy: 0.6072 - val_loss: 1.2556
# Epoch 91/300
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.5631 - loss: 1.3492 - val_accuracy: 0.6069 - val_loss: 1.2589
# Epoch 92/300

# %% [markdown]
# # 📌 Step 7: Evaluate on Test Data

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5566 - loss: 1.3310
# Test Accuracy: 0.6059

# %% [markdown]
# # 📌 Step 8: Plot Training and Validation Metrics

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Valid')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 📌 Step 9: Inference on a single image

# %%
class_labels = list(train_generator.class_indices.keys())

# %%
class_labels
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
import os

def predict_emotion(img_path):
    # Get actual class name from file path
    actual_label = os.path.basename(os.path.dirname(img_path))

    # Load and preprocess image
    img = image.load_img(img_path, color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    # Predict
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    predicted_label = class_labels[predicted_class]

    # Display image with actual & predicted label
    plt.imshow(img_array[0].squeeze(), cmap='gray')
    plt.title(f"Actual: {actual_label.capitalize()} | Predicted: {predicted_label.capitalize()}")
    plt.axis('off')
    plt.show()

# %%
predict_emotion("/content/test/happy/PrivateTest_13103594.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step

# %%
predict_emotion("/content/test/surprise/PrivateTest_13683211.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
predict_emotion("/content/test/fear/PrivateTest_11014592.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
predict_emotion("/content/test/sad/PrivateTest_10814167.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
